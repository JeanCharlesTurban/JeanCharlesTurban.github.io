# %%
import pandas as pd

# %%
df = pd.read_csv("data_preprocessing/consolidated_companies_dataset.csv")

# %%
df.head()
# Out:
#           Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 0      3-D Man          80.0      35.0   45.0        35.0   25.0    55.0
# 1       A-Bomb          75.0     100.0   20.0        80.0   25.0    65.0
# 2   Abe Sapien          95.0      30.0   35.0        65.0  100.0    85.0
# 3     Abin Sur          80.0      90.0   55.0        65.0  100.0    65.0
# 4  Abomination          85.0      80.0   55.0        90.0   65.0    95.0
#
#                 Full name            Creator Alignment     ...      \
# 0        Charles Chandler      Marvel Comics      good     ...
# 1  Richard Milhouse Jones      Marvel Comics      good     ...
# 2          Abraham Sapien  Dark Horse Comics      good     ...
# 3                       -          DC Comics      good     ...
# 4            Emil Blonsky      Marvel Comics       bad     ...
#
#   Web Creation Reality Warping Odin Force  Symbiote Costume Speed Force  \
# ...

# %%
df[["Weight"]]
# Out:
#                 Weight
# 0      200 lb // 90 kg
# 1     980 lb // 441 kg
# 2      145 lb // 65 kg
# 3      200 lb // 90 kg
# 4     980 lb // 441 kg
# 5         - lb // 0 kg
# 6     270 lb // 122 kg
# 7         - lb // 0 kg
# 8      195 lb // 88 kg
# 9      181 lb // 81 kg
# 10    230 lb // 104 kg
# 11    240 lb // 108 kg
# 12     200 lb // 90 kg
# 13        - lb // 0 kg
# 14        - lb // 0 kg
# 15    375 lb // 169 kg
# 16    385 lb // 173 kg
# 17    225 lb // 101 kg
# 18        - lb // 0 kg
# 19     150 lb // 68 kg
# 20        - lb // 0 kg
# 21     126 lb // 57 kg
# 22     121 lb // 54 kg
# 23        - lb // 0 kg
# 24     185 lb // 83 kg
# 25     200 lb // 90 kg
# 26    270 lb // 122 kg
# 27     190 lb // 86 kg
# 28        - lb // 0 kg
# 29        - lb // 0 kg
# ..                 ...
# 573    120 lb // 54 kg
# 574       - lb // 0 kg
# 575     90 lb // 41 kg
# 576   300 lb // 135 kg
# 577    140 lb // 63 kg
# 578    175 lb // 79 kg
# 579   360 lb // 162 kg
# 580    210 lb // 95 kg
# ...

# %%
df = pd.read_csv("tmp.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d5aac3e939b9> in <module>()
# ----> 1 df = pd.read_csv("tmp.csv")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
df = pd.read_csv("data_preprocessing/tmp.csv")

# %%
df.head()
# Out:
#           name            creator   weight (kg)   height (cm)
# 0      3-D Man      Marvel Comics            90           188
# 1       A-Bomb      Marvel Comics           441           203
# 2   Abe Sapien  Dark Horse Comics            65           191
# 3     Abin Sur          DC Comics            90           185
# 4  Abomination      Marvel Comics           441           203

# %%
df
# Out:
#                 name            creator   weight (kg)   height (cm)
# 0            3-D Man      Marvel Comics            90           188
# 1             A-Bomb      Marvel Comics           441           203
# 2         Abe Sapien  Dark Horse Comics            65           191
# 3           Abin Sur          DC Comics            90           185
# 4        Abomination      Marvel Comics           441           203
# 5            Abraxas      Marvel Comics             0             0
# 6      Absorbing Man      Marvel Comics           122           193
# 7        Adam Monroe       NBC - Heroes             0             0
# 8       Adam Strange          DC Comics            88           185
# 9          Agent Bob      Marvel Comics            81           178
# 10        Agent Zero      Marvel Comics           104           191
# 11        Air-Walker      Marvel Comics           108           188
# 12              Ajax      Marvel Comics            90           193
# ...

# %%
df.describe()
# Out:
#         weight (kg)   height (cm)
# count  6.030000e+02    603.000000
# mean   1.644275e+05    246.122720
# std    3.682747e+06   1366.708286
# min    0.000000e+00      0.000000
# 25%    7.000000e+00    158.500000
# 50%    7.200000e+01    178.000000
# 75%    9.900000e+01    188.000000
# max    9.000000e+07  30480.000000

# %%
df2 = pd.read_csv("tmp.csv")

# %%
df2.head()
# Out:
#           name            creator   weight (kg)   height (cm)
# 0      3-D Man      Marvel Comics          90.0         188.0
# 1       A-Bomb      Marvel Comics         441.0         203.0
# 2   Abe Sapien  Dark Horse Comics          65.0         191.0
# 3     Abin Sur          DC Comics          90.0         185.0
# 4  Abomination      Marvel Comics         441.0         203.0

# %%
df2
# Out:
#                 name            creator   weight (kg)   height (cm)
# 0            3-D Man      Marvel Comics          90.0         188.0
# 1             A-Bomb      Marvel Comics         441.0         203.0
# 2         Abe Sapien  Dark Horse Comics          65.0         191.0
# 3           Abin Sur          DC Comics          90.0         185.0
# 4        Abomination      Marvel Comics         441.0         203.0
# 5            Abraxas      Marvel Comics           NaN           NaN
# 6      Absorbing Man      Marvel Comics         122.0         193.0
# 7        Adam Monroe       NBC - Heroes           NaN           NaN
# 8       Adam Strange          DC Comics          88.0         185.0
# 9          Agent Bob      Marvel Comics          81.0         178.0
# 10        Agent Zero      Marvel Comics         104.0         191.0
# 11        Air-Walker      Marvel Comics         108.0         188.0
# 12              Ajax      Marvel Comics          90.0         193.0
# ...

# %%
df2.describe()
# Out:
#         weight (kg)   height (cm)
# count  4.470000e+02    447.000000
# mean   2.218057e+05    235.373602
# std    4.277119e+06    598.880972
# min    1.400000e+01     64.000000
# 25%    6.150000e+01    175.000000
# 50%    8.300000e+01    183.000000
# 75%    1.130000e+02    191.000000
# max    9.000000e+07  10800.000000

# %%
df2.dropna()
# Out:
#                 name            creator   weight (kg)   height (cm)
# 0            3-D Man      Marvel Comics          90.0         188.0
# 1             A-Bomb      Marvel Comics         441.0         203.0
# 2         Abe Sapien  Dark Horse Comics          65.0         191.0
# 3           Abin Sur          DC Comics          90.0         185.0
# 4        Abomination      Marvel Comics         441.0         203.0
# 6      Absorbing Man      Marvel Comics         122.0         193.0
# 8       Adam Strange          DC Comics          88.0         185.0
# 9          Agent Bob      Marvel Comics          81.0         178.0
# 10        Agent Zero      Marvel Comics         104.0         191.0
# 11        Air-Walker      Marvel Comics         108.0         188.0
# 12              Ajax      Marvel Comics          90.0         193.0
# 15             Alien  Dark Horse Comics         169.0         244.0
# 16             Amazo          DC Comics         173.0         257.0
# ...

# %%
df2.describe()
# Out:
#         weight (kg)   height (cm)
# count  4.470000e+02    447.000000
# mean   2.218057e+05    235.373602
# std    4.277119e+06    598.880972
# min    1.400000e+01     64.000000
# 25%    6.150000e+01    175.000000
# 50%    8.300000e+01    183.000000
# 75%    1.130000e+02    191.000000
# max    9.000000e+07  10800.000000

# %%
df2.loc["Wonder Girl"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [Wonder Girl] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d5d3b65481fb> in <module>()
# ----> 1 df2.loc["Wonder Girl"]
#
# ...

# %%
df2.set_index("name", inplace = True)

# %%
df2.loc[["Godzilla"]]
# Out:
#           creator   weight (kg)   height (cm)
# name
# Godzilla      NaN    90000000.0       10800.0

# %%
df2.describe()
# Out:
#         weight (kg)   height (cm)
# count  4.470000e+02    447.000000
# mean   2.218057e+05    235.373602
# std    4.277119e+06    598.880972
# min    1.400000e+01     64.000000
# 25%    6.150000e+01    175.000000
# 50%    8.300000e+01    183.000000
# 75%    1.130000e+02    191.000000
# max    9.000000e+07  10800.000000

# %%
df = pd.read_csv("final_dataset.csv")

# %%
df.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    603.000000  603.000000  603.000000  603.000000  603.000000
# mean      84.767828   46.177446   45.248756   62.131012   67.744610
# std        9.850839   32.911439   24.947210   28.995837   27.742667
# min       35.000000    5.000000   10.000000    5.000000    5.000000
# 25%       80.000000   10.000000   25.000000   35.000000   45.000000
# 50%       85.000000   40.000000   35.000000   65.000000   70.000000
# 75%       90.000000   80.000000   60.000000   90.000000  100.000000
# max      100.000000  100.000000  100.000000  100.000000  100.000000
#
#            Combat        Height         Weight  Total Power
# count  603.000000    603.000000     603.000000   603.000000
# mean    63.905473    221.824212    4593.376451   369.975124
# std     22.753833    515.988326   60582.948106   104.312929
# min     10.000000     64.000000      14.000000   115.000000
# ...
